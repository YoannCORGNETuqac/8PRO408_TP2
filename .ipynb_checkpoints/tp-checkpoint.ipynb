# %% [markdown]
# # Travail Pratique #2

# %% [markdown]
# - Yoann CORGNET (CORY14010400)
# - Emma BRAZ DA COSTA-RAMOS (BRAE21560400)
# - Edward CARAMANOS (CARE17080300)

# %% [markdown]
# ## Exercices

# %%
import pandas as pd
import numpy as np

from scipy import stats
from sklearn.cluster import KMeans

# affichage
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %%
# importation des données 
sales = pd.read_csv('data/MilwaukeePropertySalesData.csv')

# %% [markdown]
# ### Exercice 1

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ax[0].set_title("Distribution de FinishedSqft")
ax[0].hist(sales['FinishedSqft'], bins=30)
ax[0].set_xlabel("Surface habitable (pieds carrés)")
ax[0].set_ylabel("Fréquence")

ax[1].set_title("Distribution de FinishedSqft en dessous de 3000 sqft")
ax[1].hist(sales[sales['FinishedSqft'] < 3000]['FinishedSqft'], bins=30)
ax[1].set_xlabel("Surface habitable (pieds carrés)")
ax[1].set_ylabel("Fréquence");

# %% [markdown]
# Nous pouvons voir qu'en dehors des valeurs extrèmes, la variable suis une courbe relativement normal, nous pouvons donc utiliser la méthode du Z-score pour identifier les valeurs extrèmes.

# %%
# Cacule des Z-scores
z_score = stats.zscore(sales['FinishedSqft'])

print(f"Proportion de valeurs extrêmes : {len(np.abs(z_score) <= 3) * 100 / sales.size:.2f}%")

# Suppression des Z-scores extrèmes
sales = sales[np.abs(z_score) <= 3]
# Out:
# Proportion de valeurs extrêmes : 4.76%

# %% [markdown]
# La proportion de valeurs extrêmes n'est pas énorme, nous pouvons donc les supprimer.

# %%
# Affichage après nettoyage
plt.hist(sales['FinishedSqft'], bins=30)
plt.title("Distribution de FinishedSqft")
plt.xlabel("Surface habitable (pieds carrés)")
plt.ylabel("Fréquence")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Exercice 2

# %% [markdown]
# Pour savoir si effectivement le prix moyen de vente est supérieur à 250 000 $CAD dans le District 11, nous utiliserons le T-test d'échantillon unique avec un alpha de 5 %.
#
# - H0 : Le prix moyen de vente dans le District 11 est de 250 000 \$ ou moins.
# - H1 : Le prix moyen de vente dans le District 11 est supérieur à 250 000 \$.

# %%
# Filtrer les données pour ne garder que les ventes résidentielles dans le District 11
district_11_sales = sales[(sales['District'] == 11) & (sales['PropType'] == 'Residential')]['Sale_price']

plt.hist(district_11_sales, bins = 30);

# %%
# Les prix de ventes semble bien suivre une distribution normal
# nous pouvons donc effectuer le T-test
t_value, p_value = stats.ttest_1samp(district_11_sales, 250_000)

print(f"T value = {t_value:.2f}")
print(f"P value = {p_value:.2f}")
# Out:
# T value = 0.52
# P value = 0.61

# %% [markdown]
# La p-value est de 0.61 > 0.05, il n'y a donc pas assez de preuvent pour rejeter H0.
# Donc a preuve du contraire, le prix moyen de vente dans le dristrict 11 n'est pas superieur à 250 000 $.

# %% [markdown]
# ### Exercice 3

# %% [markdown]
# Un chercheur a déterminé s'il existe une différence significative de superficie habitable entre les habitations construites
# Avant 1950 et celles construites en 1950 ou après.
# Pour cela, nous utiliserons un T-test independant, avec un alpha de 0.05.
#
# - H0 : Il n'y a pas de différence significative entre les superficies habitables d'avant 1950 et d'après 1950.
# - H1 : Il y a une différence significative entre les superficies habitables d'avant 1950 et d'après 1950.

# %%
sqrft_before_1950 = sales[sales['Year_Built'] < 1950]['FinishedSqft']
sqrft_after_1950  = sales[sales['Year_Built'] >= 1950]['FinishedSqft']

fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ax[0].set_title("Distribution des surfaces avant 1950")
ax[0].hist(sqrft_before_1950, bins=30)
ax[1].set_title("Distribution des surfaces après 1950")
ax[1].hist(sqrft_after_1950, bins=30);

# %%
# Les prix de ventes semble bien suivre une distribution presque normal
# nous pouvons donc effectuer le T-test
t_value, p_value = stats.ttest_ind(sqrft_before_1950, sqrft_after_1950)

print(f"T value = {t_value:.2f}")
print(f"P value = {p_value}")
# Out:
# T value = 20.48
# P value = 8.141544232319778e-90

# %% [markdown]
# La p-value est de 8.14e-90 > 0.05, l'hypothèse nulle est donc rejetée.
# Il y a donc une différence notable de superficie habitable entre les habitations d'avant 1950 et d'après 1950.

# %% [markdown]
# ### Exercice 4

# %% [markdown]
# ### Exercice 5

# %% [markdown]
# ### Exercice 6

# %% [markdown]
# ### Exercice 7

# %% [markdown]
# On isole les données de Juin et on selection les varaibles qui nous intéressent :

# %%
sales['Sale_date'] = pd.to_datetime(sales['Sale_date'])

june_data = sales[sales['Sale_date'].dt.month == 6]

# Sale_price : Indique le prix de vente, essentiel pour analyser les ventes.
# FinishedSqft : Représente la surface habitable, une mesure clé pour la taille des propriétés.
# Bdrms : Nombre de chambres, un critère important pour segmenter les propriétés.
# Lotsize : Taille du terrain, pour inclure l'espace extérieur.
features = june_data[['Sale_price', 'FinishedSqft', 'Bdrms', 'Lotsize']].dropna()

# %% [markdown]
# On supprime les valeurs abérentes :

# %%
#Ici, on utilise la méthode IQR qui nous permet d'isoler les valeurs qui s'écarte significativement des autres, dans notre cas, 
# cela nous permet d'avoir un coude plus lisse car en gardant ces valeurs notre coude n'était pas beau 
Q1 = features.quantile(0.25)
Q3 = features.quantile(0.75)
IQR = Q3 - Q1
features = features[~((features < (Q1 - 1.5 * IQR)) | (features > (Q3 + 1.5 * IQR))).any(axis=1)]

# On standardise les valeurs
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %% [markdown]
# Détéction du point d'inflexion :

# %%
# Calculer l'intertie pour différent k
inertias = []
K_range = range(2, 11)
for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_features)
    inertias.append(kmeans.inertia_)
    
# Visualisation de la méthode du coude
plt.figure()
plt.plot(K_range, inertias, marker='o', linestyle='-', label='Inertie intra-groupe')
plt.title('Méthode du coude')
plt.xlabel('Nombre de groupes (K)')
plt.ylabel('Inertia')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# On observe un point d'inflexion pour x = 4, nous allons donc séparer nos observations en 4 groupes :

# %%
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(scaled_features)

june_data_filtered = june_data.loc[features.index].copy()
june_data_filtered['Cluster'] = clusters

# Visualisation avec le prix de vente et la surface habitable
plt.figure()
sns.scatterplot(
    x=june_data_filtered['Sale_price'], 
    y=june_data_filtered['FinishedSqft'], 
    hue=june_data_filtered['Cluster'], 
    palette='viridis'
)
plt.title('Groupes par prix de vente et surface habitable')
plt.xlabel('Prix de vente')
plt.ylabel('Surface habitable')
plt.legend(title='Groupes')
plt.show()

cluster_summary = june_data_filtered.groupby('Cluster')[['Sale_price', 'FinishedSqft', 'Bdrms', 'Lotsize']].mean()
print("Résumé des regroupements :\n", cluster_summary)
# Out:
# Résumé des regroupements :
#              Sale_price  FinishedSqft     Bdrms      Lotsize
# Cluster
# 0        114615.454545   1064.494949  2.585859  3288.383838
# 1        212195.032258   1152.664516  3.012903  6805.367742
# 2        193720.930233   1919.686047  4.220930  4902.546512
# 3        293177.966102   1493.440678  2.796610  3793.525424

# %% [markdown]
# Visualisation des groupes dans un espace réduit PCA :

# %%
pca = PCA(n_components=2)
pca_features = pca.fit_transform(scaled_features)

plt.figure()
sns.scatterplot(
    x=pca_features[:, 0], 
    y=pca_features[:, 1], 
    hue=june_data_filtered['Cluster'], 
    palette='viridis'
)
plt.title('Groupes visualisés dans un espace 2D (PCA)')
plt.xlabel('Première composante principale')
plt.ylabel('Deuxième composante principale')
plt.legend(title='Groupes')
plt.show()
